# %%
# Improve output style on Jupyter Notebook
using Logging
global_logger(ConsoleLogger(stdout));

# Install extra packages
using Pkg
Pkg.add("Glob")

# Package to time cells
using TickTock
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using RELOG
using Glob
using Logging

# %%
tick()
# Solve reference case
problem = "smallproblem"
_, model = RELOG.solve("input/$problem/InputPipelineData.json", return_model=true);

# Solve what-if scenarios
for filename in glob("input/whatif-$problem/*.json")
    solution = RELOG.resolve(model, filename)
    prefix = joinpath(
        "output",
        "whatif-$problem",
        replace(basename(filename), ".json" => ""),
    )
    RELOG.write_plants_report(solution, "$(prefix)_plants.csv")
    RELOG.write_products_report(solution, "$(prefix)_products.csv")
    RELOG.write_plant_outputs_report(solution, "$(prefix)_plant_outputs.csv")
    RELOG.write_plant_emissions_report(solution, "$(prefix)_plant_emissions.csv")
    RELOG.write_transportation_report(solution, "$(prefix)_tr.csv")
    RELOG.write_transportation_emissions_report(solution, "$(prefix)_tr_emissions.csv")
end
tock()
# Out:
# [ Info:  started timer at: 2023-01-18T10:47:50.435
# [ Info: Reading input/smallproblem/InputPipelineData.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building optimization model...
# [ Info: Optimizing MILP...
# [ Info: Re-optimizing with integer variables fixed...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.25_cost_0.0.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.25_cost_100.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.25_cost_150.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.25_cost_300.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.25_cost_50.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.25_cost_600.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.5_cost_0.0.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.5_cost_100.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.5_cost_150.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.5_cost_300.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.5_cost_50.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_0.5_cost_600.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_1_cost_0.0.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_1_cost_100.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_1_cost_150.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_1_cost_300.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_1_cost_50.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_1_cost_600.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_2_cost_0.0.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_2_cost_100.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_2_cost_150.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_2_cost_300.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_2_cost_50.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_2_cost_600.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_4_cost_0.0.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_4_cost_100.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_4_cost_150.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_4_cost_300.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_4_cost_50.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info: Reading input/whatif-smallproblem/storage_ultra_cap_4_cost_600.json...
# [ Info:         1130 collection centers
# [ Info:           10 candidate plant locations
# [ Info: Building new graph...
# [ Info:                5 time periods
# [ Info:               10 process nodes
# [ Info:              100 shipping nodes (plant)
# [ Info:             1130 shipping nodes (collection)
# [ Info:            11400 arcs
# [ Info: Building new optimization model...
# [ Info: Fixing decision variables...
# [ Info: Optimizing MILP...
# [ Info: Extracting solution...
# [ Info:         35.125735125s: 35 seconds, 125 milliseconds
